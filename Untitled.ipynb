# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
epoch = 0
batch = 1

# %%
# Y = np.load(f'training/analysis/learned_target_epoch_{epoch}_batch_{batch}.npy')
# Y_prime = np.load(f'training/analysis/learned_preds_{epoch}_batch_{batch}.npy')

Y = np.load(f'training/analysis/pred_on_target_off_{epoch}_batch_{batch}.npy')
Y_prime = np.load(f'training/analysis/pred_on_target_{epoch}_batch_{batch}.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [143], line 5
#       1 # Y = np.load(f'training/analysis/learned_target_epoch_{epoch}_batch_{batch}.npy')
#       2 # Y_prime = np.load(f'training/analysis/learned_preds_{epoch}_batch_{batch}.npy')
#       4 Y = np.load(f'training/analysis/pred_on_target_off_{epoch}_batch_{batch}.npy')
# ----> 5 Y_prime = np.load(f'training/analysis/pred_on_target_{epoch}_batch_{batch}.npy')
#
# File ~\Anaconda\envs\torchy\lib\site-packages\numpy\lib\npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     388     own_fid = False
#     389 else:
# --> 390     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     391     own_fid = True
#     393 # Code to distinguish from NumPy binary files and pickles.
#
# ...

# %%
# agg = pd.Series(X.flatten())
gt = pd.Series(Y.flatten())
pred = pd.Series(Y_prime.flatten())

# %%
gt.plot(figsize=(14,7), label='GT')
pred.plot(figsize=(14,7), label='PRED')
plt.legend()
