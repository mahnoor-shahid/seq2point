# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
exp = 3
epoch = 1
batch = 295

# %%
Y = np.load(f'training/analysis/exp{exp}/learned_target_epoch_{epoch}_batch_{batch}.npy')
Y_prime = np.load(f'training/analysis/exp{exp}/learned_preds_epoch_{epoch}_batch_{batch}.npy')

# Y = np.load(f'training/analysis/learned_target_epoch_{epoch}_batch_{batch}.npy')
# Y_prime = np.load(f'training/analysis/learned_preds_epoch_{epoch}_batch_{batch}.npy')

# %%
# agg = pd.Series(X.flatten())
gt = pd.Series(Y.flatten())
pred = pd.Series(Y_prime.flatten())

# %%
gt.plot(figsize=(15,7), label='Target Appliance')
pred.plot(figsize=(15,7), label='Predicted')
plt.grid()
plt.legend(loc="upper left")
# plt.title(f'Batch {batch}')
plt.title(f'Epoch {epoch}')
# Out:
# Text(0.5, 1.0, 'Epoch 1')

# %%
from sklearn.metrics import classification_report
y_true = [0, 1, 2, 2, 2]
y_pred = [0, 0, 2, 2, 1]
target_names = ['class 0', 'class 1', 'class 2']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.50      1.00      0.67         1
#      class 1       0.00      0.00      0.00         1
#      class 2       1.00      0.67      0.80         3
#
#     accuracy                           0.60         5
#    macro avg       0.50      0.56      0.49         5
# weighted avg       0.70      0.60      0.61         5

# %%
def a ():

    return 23, 44, 7

# %%
results = a()

# %%
results[0]
# Out:
# 23

# %%
from sklearn.preprocessing import StandardScaler
import os, pickle

# %%
_X_scaler, _y_scaler = StandardScaler(), StandardScaler()

# %%
dates = pd.date_range(start='2022-11-12', end = '2022-11-13', freq='T')
df = pd.DataFrame({'dates':dates, 'x': np.arange(0, len(dates)), 'y': np.arange(100, len(dates)+100)}).set_index('dates')

# %%
df
# Out:
#                         x     y
# dates
# 2022-11-12 00:00:00     0   100
# 2022-11-12 00:01:00     1   101
# 2022-11-12 00:02:00     2   102
# 2022-11-12 00:03:00     3   103
# 2022-11-12 00:04:00     4   104
# ...                   ...   ...
# 2022-11-12 23:56:00  1436  1536
# 2022-11-12 23:57:00  1437  1537
# 2022-11-12 23:58:00  1438  1538
# 2022-11-12 23:59:00  1439  1539
# 2022-11-13 00:00:00  1440  1540
#
# [1441 rows x 2 columns]

# %%
_X_scaler.fit(df[df.columns[0]].values.reshape(-1, 1))
_y_scaler.fit(df[df.columns[-1]].values.reshape(-1, 1))
# Out:
# StandardScaler()

# %%
_y_scaler
# Out:
# StandardScaler()

# %%
import sys

# %%
pickle.dump(_X_scaler, open(os.path.join('./scalers/', 'X_scaler.sav'), 'wb'))
pickle.dump(_y_scaler, open(os.path.join('scalers/', 'y_scaler.sav'), 'wb'))
X = _X_scaler.transform(df[df.columns[0]].values.reshape(-1,1)).flatten()
y = _y_scaler.transform(df[df.columns[-1]].values.reshape(-1,1)).flatten()

# %%
X
# Out:
# array([-1.73084925, -1.72844529, -1.72604133, ...,  1.72604133,
#         1.72844529,  1.73084925])

# %%
sys.path.extend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 sys.path.extend()
#
# TypeError: list.extend() takes exactly one argument (0 given)
